# %%
import pandas as pd
pd.set_option('display.max_columns',None)

# %%
treesdata=pd.read_csv("2015Street_Tree_CensusData.csv")
treesdata.head()
# Out:
#    tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   180683    348711  08/27/2015         3           0   OnCurb  Alive   Fair
# 1   200540    315986  09/03/2015        21           0   OnCurb  Alive   Fair
# 2   204026    218365  09/05/2015         3           0   OnCurb  Alive   Good
# 3   204337    217969  09/05/2015        10           0   OnCurb  Alive   Good
# 4   189565    223043  08/30/2015        21           0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common steward guards  \
# 0                         Acer rubrum        red maple    None   None
# 1                   Quercus palustris          pin oak    None   None
# 2  Gleditsia triacanthos var. inermis      honeylocust    1or2   None
# 3  Gleditsia triacanthos var. inermis      honeylocust    None   None
# 4                     Tilia americana  American linden    None   None
#
#    sidewalk         user_type problems root_stone root_grate root_other  \
# ...

# %%
treesdata.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
treedata_subset=treesdata[['tree_id','created_at', 'tree_dbh', 'stump_diam',
       'status', 'health', 'spc_common', 'steward',
       'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
       'root_grate', 'trunk_wire', 'trnk_light',
       'brch_light', 'brch_shoe', 'brch_other','zip_city', 'state']]
treedata_subset
# Out:
#         tree_id  created_at  tree_dbh  stump_diam status health  \
# 0        180683  08/27/2015         3           0  Alive   Fair
# 1        200540  09/03/2015        21           0  Alive   Fair
# 2        204026  09/05/2015         3           0  Alive   Good
# 3        204337  09/05/2015        10           0  Alive   Good
# 4        189565  08/30/2015        21           0  Alive   Good
# ...         ...         ...       ...         ...    ...    ...
# 683783   155433  08/18/2015        25           0  Alive   Good
# 683784   183795  08/29/2015         7           0  Alive   Good
# 683785   166161  08/22/2015        12           0  Alive   Good
# 683786   184028  08/29/2015         9           0  Alive   Good
# 683787   200607  09/03/2015        23           0  Alive   Fair
#
#                  spc_common steward guards  sidewalk         user_type  \
# 0                 red maple    None   None  NoDamage  TreesCount Staff
# ...

# %%
treedata_subset.isna().sum()
# Out:
# tree_id           0
# created_at        0
# tree_dbh          0
# stump_diam        0
# status            0
# health        31616
# spc_common    31619
# steward       31615
# guards        31616
# sidewalk      31616
# user_type         0
# problems      31664
# root_stone        0
# root_grate        0
# trunk_wire        0
# trnk_light        0
# brch_light        0
# brch_shoe         0
# brch_other        0
# zip_city          0
# state             0
# dtype: int64

# %%
treedata_subset[treedata_subset['health'].isna()]
# Out:
#         tree_id  created_at  tree_dbh  stump_diam status health spc_common  \
# 37       211205  09/09/2015         0          16  Stump    NaN        NaN
# 57       187807  08/29/2015         0           0   Dead    NaN        NaN
# 196      208322  09/07/2015        10           0   Dead    NaN        NaN
# 209      209058  09/08/2015         6           0   Dead    NaN        NaN
# 239      203597  09/04/2015         0          15  Stump    NaN        NaN
# ...         ...         ...       ...         ...    ...    ...        ...
# 683693   156162  08/18/2015         3           0   Dead    NaN        NaN
# 683695   170888  08/24/2015         0           5  Stump    NaN        NaN
# 683697   177922  08/26/2015         0          17  Stump    NaN        NaN
# 683698   193791  09/01/2015         3           0   Dead    NaN        NaN
# 683699   172660  08/25/2015         0           4  Stump    NaN        NaN
#
# ...

# %%
treedata_subset.describe()
# Out:
#              tree_id       tree_dbh     stump_diam
# count  683788.000000  683788.000000  683788.000000
# mean   365205.011085      11.279787       0.432463
# std    208122.092902       8.723042       3.290241
# min         3.000000       0.000000       0.000000
# 25%    186582.750000       4.000000       0.000000
# 50%    366214.500000       9.000000       0.000000
# 75%    546170.250000      16.000000       0.000000
# max    722694.000000     450.000000     140.000000

# %%
treedata_subset.dtypes
# Out:
# tree_id        int64
# created_at    object
# tree_dbh       int64
# stump_diam     int64
# status        object
# health        object
# spc_common    object
# steward       object
# guards        object
# sidewalk      object
# user_type     object
# problems      object
# root_stone    object
# root_grate    object
# trunk_wire    object
# trnk_light    object
# brch_light    object
# brch_shoe     object
# brch_other    object
# zip_city      object
# state         object
# dtype: object

# %%
treedata_subset.hist(bins=60,figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'tree_id'}>,
#         <AxesSubplot:title={'center':'tree_dbh'}>],
#        [<AxesSubplot:title={'center':'stump_diam'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
bigtree=treedata_subset[treedata_subset['stump_diam']>55]
bigtree
# Out:
#         tree_id  created_at  tree_dbh  stump_diam status health spc_common  \
# 6466     166008  08/22/2015         0          72  Stump    NaN        NaN
# 7042     206818  09/06/2015         0         100  Stump    NaN        NaN
# 9883     207003  09/06/2015         0          70  Stump    NaN        NaN
# 11342    206819  09/06/2015         0         140  Stump    NaN        NaN
# 22452    228273  09/15/2015         0          90  Stump    NaN        NaN
# ...         ...         ...       ...         ...    ...    ...        ...
# 626442    97902  07/27/2015         0          66  Stump    NaN        NaN
# 645994   135904  08/11/2015         0          65  Stump    NaN        NaN
# 649174   154188  08/17/2015         0          65  Stump    NaN        NaN
# 652690   154181  08/17/2015         0          60  Stump    NaN        NaN
# 653066   154190  08/17/2015         0          80  Stump    NaN        NaN
#
# ...

# %%
bigtree[['tree_id','stump_diam']].plot(kind='scatter',x='tree_id',y='stump_diam',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='tree_id', ylabel='stump_diam'>

# %%
pd.DataFrame(treedata_subset['spc_common'].value_counts()).plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
treedata_subset['steward'].value_counts()
# Out:
# None       487823
# 1or2       143557
# 3or4        19183
# 4orMore      1610
# Name: steward, dtype: int64

# %%
treedata_subset['sidewalk'].value_counts()
# Out:
# NoDamage    464978
# Damage      187194
# Name: sidewalk, dtype: int64

# %%
tree_problems=treedata_subset[[ 'root_stone',
       'root_grate', 'trunk_wire', 'trnk_light',
       'brch_light', 'brch_shoe', 'brch_other']]
tree_problems
# Out:
#        root_stone root_grate trunk_wire trnk_light brch_light brch_shoe  \
# 0              No         No         No         No         No        No
# 1             Yes         No         No         No         No        No
# 2              No         No         No         No         No        No
# 3             Yes         No         No         No         No        No
# 4             Yes         No         No         No         No        No
# ...           ...        ...        ...        ...        ...       ...
# 683783         No         No         No         No         No        No
# 683784         No         No         No         No         No        No
# 683785         No         No         No         No         No        No
# 683786         No         No         No         No         No        No
# 683787         No         No         No         No         No        No
#
#        brch_other
# 0              No
# 1              No
# 2              No
# 3              No
# ...

# %%
tree_problems.apply(pd.Series.value_counts)
# Out:
#      root_stone  root_grate  trunk_wire  trnk_light  brch_light  brch_shoe  \
# No       543789      680252      670514      682757      621423     683377
# Yes      139999        3536       13274        1031       62365        411
#
#      brch_other
# No       659433
# Yes       24355
