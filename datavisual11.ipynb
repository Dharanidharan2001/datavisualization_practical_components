# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
sns.set(style='darkgrid')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
f=sns.load_dataset('flights')
f.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
sns.relplot(x='passengers',y='month',data=f)

# %%
sns.relplot(x='passengers',y='month',hue='year',data=f)

# %%
sns.relplot(x='passengers',y='month',hue='year',palette="ch:r=-.5,l=.75",data=f)

# %%
g=sns.relplot(x='passengers',y='year',data=f,kind='line')
g.fig.autofmt_xdate()

# %%
a=pd.DataFrame({'Day':[1,2,3,4,5,6,7],'Grocery':[30,80,45,23,51,46,76],'Clothes':[13,40,34,23,54,67,98],'Utensils':[12,32,27,56,87,54,34]},index=[1,2,3,4,5,6
,7])
g=sns.relplot(x='Day',y='Clothes',data=a,kind='line')
g.fig.autofmt_xdate()

# %%
sns.set(style='ticks',color_codes=True)
t=sns.load_dataset('tips')
t.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='day',y='total_bill',data=t)

# %%
sns.catplot(x='day',y='tip',data=t)

# %%
sns.catplot(x='day',y='total_bill',hue='time',data=t)

# %%
sns.catplot(x='day',y='total_bill',kind='violin',hue='time',data=t)

# %%
sns.catplot(x='day',y='total_bill',kind='box',hue='time',data=t)

# %%
d1=np.random.normal(size=100)
d1
sns.displot(d1)

# %%
sns.kdeplot(d1)

# %%
p=sns.load_dataset('penguins')
p
sns.jointplot(data=p,x='bill_length_mm',y='bill_depth_mm')

# %%
sns.jointplot(data=p,x='bill_length_mm',y='bill_depth_mm',hue='species')

# %%
sns.jointplot(data=p,x='bill_length_mm',y='bill_depth_mm',hue='species',kind='kde')

# %%
sns.jointplot(data=p,x='bill_length_mm',y='bill_depth_mm',kind='reg')

# %%
sns.jointplot(data=p,x='bill_length_mm',y='bill_depth_mm',kind='hex')

# %%
sns.jointplot(data=p,x='bill_length_mm',y='bill_depth_mm',markers='*',s=100,marginal_kws=dict(bins=25,fill=False))

# %%
sns.set(style='darkgrid')
a=sns.load_dataset('iris')
b=sns.FacetGrid(a,col='species')
b.map(plt.hist, 'sepal_length')

# %%
b=sns.FacetGrid(a,col='species')
b.map(plt.hist,'sepal_width')

# %%
sns.set(style='ticks')
a=sns.load_dataset('flights')
b=sns.PairGrid(a)
b.map(plt.scatter)

# %%
sns.set(style='white',color_codes=True)
a=sns.load_dataset('tips')
sns.boxplot(data=a,x='day',y='total_bill')

# %%
sns.boxplot(data=a,x='day',y='total_bill')
sns.despine(offset=10,trim=True)

# %%
sns.set()
presentcolors=sns.color_palette()
sns.palplot(presentcolors)
